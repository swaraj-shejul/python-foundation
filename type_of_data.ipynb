# %% [markdown]
# # type()
#
# - this funstion use to check the type for object

# %%
a,b,c,d =1,'swaraj',{1,3,4},[1,2,3]
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'set'>
# <class 'list'>

# %% [markdown]
# # isinstance()
#
# - use to check the the object is of given type or not
# - boolean output

# %%
a,b,c,d =1,'swaraj',{1,3,4},[1,2,3]

print(isinstance(d,list))
print(isinstance(a,str))
# Out:
# True
# False
