# %% [markdown]
# # BMI Calculator
#
#
# 1. Prompt the user "Enter your weight (in kgs)" and record weight
# 2. Prompt the user "What is your preferred unit of height? Type "F" for feet and "M" for meters"
# and record the preference
# 3. If user says "F" then prompt user "You will enter your height given as feet and inches. First
# enter feet" and record feet and then prompt user 'Now enter inches" and record inches
# 4. If user says "M" then prompt user "What is your height in meters" and record height in
# meters
# 5. If user had chosen "F" then convert height into meters
# 6. Compute BMI using the following formula
#    BMI = Weight (in kgs) / Height**2 (in m)
# 8. Depending on the value of BMI, report the user's type given by the following table:
# - BMI < 18.5 : UNDERWEIGHT
# - 18.5 <= BMI <25 : NORMAL
# - 25 <= BMI < 30 : OVERWEIGHT
# - BMI > 30 : VERY-OVERWEIGHT

# %%
weight = eval(input("Enter your weight (in kgs): "))
height = input("What is your preferred unit of height? Type 'F' for feet and 'M' for meters")
if height.upper() == "F":
    h_feet = eval (input("You will enter your height given as feet and inches. First enter feet : "))
    h_inches = eval(input('Now enter inches : '))
    h_meter = ((int(h_feet) * 12) + int(h_inches)) * 0.0254
    BMI = int(weight) / h_meter**2
elif height.upper() == "M":
    h_meters = eval(input("What is your height in meters : "))
    BMI = int(weight) / h_meter**2
else:
    print("Type 'F' for feet and 'M' for meters")


if BMI < 18.5 :
    print ("your BMI is : ",BMI," Says you are UNDERWEIGHT")
elif BMI >= 18.5 and BMI <25 :
    print ("your BMI is : ",BMI," Says you are NORMAL")
elif BMI >= 25 and BMI  < 30 :
    print ("your BMI is : ",BMI," Says you are OVERWEIGHT")
elif BMI > 30 :
    print ("your BMI is : ",BMI," Says you are VERY-OVERWEIGHT")
# Out:
# Enter your weight (in kgs):  100
# What is your preferred unit of height? Type 'F' for feet and 'M' for meters f
# You will enter your height given as feet and inches. First enter feet :  5.2
# Now enter inches :  2
# your BMI is :  40.32266129048387  Says you are VERY-OVERWEIGHT
