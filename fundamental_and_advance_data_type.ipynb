# %% [markdown]
# # Fandamental Data Type
#     - It is use to store singe value in a single object
#     - fandamental data types
#             - Int
#             - Float
#             - String
#             - complex
#             this are the fandamental data types and can store only single value in the object

# %% [markdown]
# # Advance Data Type
#     - It is use to store multiple values in the single object
#     - Adavance data types
#             - List
#             - Tuple
#             - Set
#             - Dictionary
#             this are the advance data types and can store the multiple values and also multiple types of valuse in a single object
