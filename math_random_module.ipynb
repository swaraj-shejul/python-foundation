# %% [markdown]
# # Important Modules

# %% [markdown]
# # 1) math
#
#
# - it will provide some important functions required in gen ai and ml

# %%
import math

# %%
math.log(79)
# Out:
# 4.3694478524670215

# %%
math.log10(79) # alwase base 10
# Out:
# 1.8976270912904414

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math.exp(2)
# Out:
# 7.38905609893065

# %%
math.exp(4)
# Out:
# 54.598150033144236

# %% [markdown]
# # 2) Random
#
# - this module defines several functions to generate random numbers.
# - we can use these functions while developing games, in cryptography and to generate random numbers on fly for authentication

# %%
import random

# %%
random.random()
# Out:
# 0.3399621247382112

# %%
random.randint(1,10)
# Out:
# 8

# %%
random.randrange(5,100,5)
# Out:
# 95

# %%
print(random.choice(["swaraj","shantty","shejul","buntty"]))
print(random.choice((1,2,3,4,5)))
# Out:
# shejul
# 4

# %%
random.choice()
